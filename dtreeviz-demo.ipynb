# %%
# !pip install dtreeviz
# Out:
# Requirement already satisfied: dtreeviz in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (2.3.2)
# Requirement already satisfied: graphviz>=0.9 in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from dtreeviz) (0.21)
# Requirement already satisfied: pandas in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from dtreeviz) (2.3.3)
# Requirement already satisfied: numpy in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from dtreeviz) (2.3.5)
# Requirement already satisfied: scikit-learn in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from dtreeviz) (1.8.0)
# Requirement already satisfied: matplotlib in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from dtreeviz) (3.10.0)
# Requirement already satisfied: colour in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from matplotlib->dtreeviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from matplotlib->dtreeviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from matplotlib->dtreeviz) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from matplotlib->dtreeviz) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from matplotlib->dtreeviz) (25.0)
# Requirement already satisfied: pillow>=8 in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from matplotlib->dtreeviz) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from matplotlib->dtreeviz) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from pandas->dtreeviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from pandas->dtreeviz) (2025.2)
# Requirement already satisfied: scipy>=1.10.0 in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from scikit-learn->dtreeviz) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from scikit-learn->dtreeviz) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (from scikit-learn->dtreeviz) (3.5.0)

# %%
import graphviz.backend as be

# %%
from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG
from sklearn.tree import DecisionTreeRegressor , DecisionTreeClassifier

# %%
clas = DecisionTreeClassifier()  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'x[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'x[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8461538461538461, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# 1. Classification

# %%
import dtreeviz

viz_model = dtreeviz.model(
    clas,
    X_train,
    y_train,
    feature_names=iris.feature_names,
    target_name="iris",
    class_names=["setosa", "versicolor", "virginica"]
)

viz_model.view(fontname="DejaVu Sans")

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /home/sudhanshu-jain/anaconda3/lib/python3.13/site-packages (0.21)

# %% [markdown]
# 2. Regression

# %%
from sklearn.datasets import fetch_california_housing


def load_boston():
    return fetch_california_housing()

regr = DecisionTreeRegressor(max_depth=1)
boston = load_boston()

X_train = boston.data
y_train = boston.target
regr.fit(X_train, y_train)

viz = dtreeviz.model(
    regr,
    X_train,
    y_train,
    target_name='price',
    feature_names=boston.feature_names
)
viz.view(fontname="DejaVu Sans")

# %% [markdown]
# ### 4. Show prediction path
